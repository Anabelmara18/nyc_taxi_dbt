# %%
# %sql
DROP MATERIALIZED VIEW IF EXISTS trip_data.trip_source.gold_daily_summary;

# %%
# %sql
SELECT COUNT(*)  FROM trip_data.trip_source.gold
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>2870071</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS total_rows,
       COUNT(DISTINCT trip_date) AS distinct_values
FROM trip_data.trip_source.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th><th>distinct_values</th></tr></thead><tbody><tr><td>2870071</td><td>33</td></tr></tbody></table></div>
